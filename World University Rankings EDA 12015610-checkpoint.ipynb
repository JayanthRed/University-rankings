# %% [markdown]
# # EXPLANATORY DATA ANALYSIS
#
# # DATASET : World University Rankings
#
# AS A PART OF EXPLANTORY DATA ANALYSIS(EDA) PROJECT , I SELECTED THE DATASET NAMED "WORLD UNIVERSITY RANKINGS" IN WHICH WE ARE GOING TO THE VISUALIZE THE RELATIONS BETWEEN THE RATINGS OF DIFFERENT UNIVERSITIES IN DIFFERENT PARTS OF WORLD . USING THE LIBRARIES 'NUMPY','PANDAS','MATPLOTLIB','SEABORN','PLOTLY','ITERTOOLS'.
#
# NumPy Library:NumPy can be used to perform a wide variety of mathematical operations.
#
# Pandas Library:It is a python package that offers various operations for manipulating numerical data and time series. It is mainly popular for importing and analyzing data much easier.
#
# Matplotlib Library: Matplotlib is a cross-platform, data visualization and graphical plotting library for python and its numerical extension NumPy.
#
# Seaborn Library: It is a python data visulization library based on matplotlib. It provides a high-level interface for drawing attractive and infromative statistical graphics.
#
# Itertools : Itertools is a module in python , it is used iterate over data structures that can be stepped over using a for-loop. This module works as a fast, memory as a fast, memory-effecient tool thatr is used either by themselves or in combination to form iterator algebra.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import itertools
# %matplotlib inline
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot 
import warnings
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Here I downloaded the csv file of the World University Rankings from the resource available to me.I imported that csv file to the jupyter and the next step is to read the data which is available in csv file , which I had imported to the jupyter

# %%
uni = pd.read_csv("C:\\Users\\JAYANTH\\OneDrive\\Desktop\\cwurData.csv")

# %% [markdown]
#  The code uni.head() returns the output of first five rows of the data

# %%
uni.head(5)
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %% [markdown]
# The code uni.tail() returns the output of last five rows of the data

# %%
uni.tail(5)
# Out:
#       world_rank                      institution   country  national_rank  \
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 2195                   367                567                 218
# 2196                   236                566                 218
# 2197                   367                549                 218
# 2198                   367                567                 218
# 2199                   367                567                 218
#
#       publications  influence  citations  broad_impact  patents  score  year
# ...

# %% [markdown]
# Here uni.describe() gives the total summary of the data by mean, median,mode and total count

# %%
uni.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %% [markdown]
# uni.info() gives the output that the total columns that data consists and the no.of non-null entries in the data and the data type whether it is a object ,float,integer etc....

# %%
uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# ...

# %% [markdown]
# uni.shape() gives the output result the number of rows and columns that datatset is consisting.

# %%
uni.shape
# Out:
# (2200, 14)

# %% [markdown]
# uni.isnull() is used for verifying whether dataset consists of an null entries and in the output we can clearly observe that the column "broad_impact" is a null entry.

# %%
uni.isnull()
# Out:
#       world_rank  institution  country  national_rank  quality_of_education  \
# 0          False        False    False          False                 False
# 1          False        False    False          False                 False
# 2          False        False    False          False                 False
# 3          False        False    False          False                 False
# 4          False        False    False          False                 False
# ...          ...          ...      ...            ...                   ...
# 2195       False        False    False          False                 False
# 2196       False        False    False          False                 False
# 2197       False        False    False          False                 False
# 2198       False        False    False          False                 False
# 2199       False        False    False          False                 False
#
# ...

# %% [markdown]
# # Data Cleaning & Handling

# %% [markdown]
# It is used to check the null values

# %%
uni.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %% [markdown]
# count the missing values in broad_impact

# %%
uni.broad_impact.isnull().sum()
# Out:
# 200

# %%
uni.broad_impact.describe()
# Out:
# count    2000.000000
# mean      496.699500
# std       286.919755
# min         1.000000
# 25%       250.500000
# 50%       496.000000
# 75%       741.000000
# max      1000.000000
# Name: broad_impact, dtype: float64

# %% [markdown]
# # Drop the records with broad_impact missing

# %% [markdown]
# drop the records with age missing in uni and copy in uni dataframe.

# %%
uni= uni[-uni.broad_impact.isnull()].copy()
uni.shape
# Out:
# (2000, 14)

# %% [markdown]
# # handling missing values in broad_impact

# %% [markdown]
# find the mode of broad_impact in df1

# %%
broad_impact_mode = uni.broad_impact.mode()[0]
broad_impact_mode
# Out:
# 642.0

# %% [markdown]
# fill missing values with mode value ofbroad_impact in uni

# %%
uni.broad_impact.fillna(broad_impact_mode,inplace=True)
uni.broad_impact.value_counts(normalize=True)
# Out:
# 642.0    0.0105
# 849.0    0.0100
# 800.0    0.0095
# 783.0    0.0085
# 715.0    0.0085
#           ...
# 36.0     0.0005
# 105.0    0.0005
# 144.0    0.0005
# 115.0    0.0005
# 43.0     0.0005
# Name: broad_impact, Length: 343, dtype: float64

# %% [markdown]
# to check the null values if there are not in broad_impact

# %%
uni.broad_impact.isnull().sum()
# Out:
# 0

# %% [markdown]
# Here uni.world_rank.describe() gives the total summary of the data by mean, median,mode and total count in world_rank column

# %%
uni.world_rank.describe()
# Out:
# count    2000.000000
# mean      500.500000
# std       288.747186
# min         1.000000
# 25%       250.750000
# 50%       500.500000
# 75%       750.250000
# max      1000.000000
# Name: world_rank, dtype: float64

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# Here uni.broad_impact.describe() gives the total summary of the data by mean, median,mode and total count in broad_impact column

# %%
uni.broad_impact.describe()
# Out:
# count    2000.000000
# mean      496.699500
# std       286.919755
# min         1.000000
# 25%       250.500000
# 50%       496.000000
# 75%       741.000000
# max      1000.000000
# Name: broad_impact, dtype: float64

# %% [markdown]
# Histogram

# %%
uni.broad_impact.plot.hist()
plt.show()

# %% [markdown]
# Boxplot

# %%
sns.boxplot(uni.broad_impact)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Distribution plot

# %%
world_rank = uni['world_rank']
plt.figure(figsize=(12,10))
plt.title('Distribution Plot', fontsize=15)
plt.xlabel('xlabel',fontsize=15)
sns.distplot(uni['world_rank'] , color='g')
# Out:
# <AxesSubplot:title={'center':'Distribution Plot'}, xlabel='world_rank', ylabel='Density'>

# %%
plt.figure(figsize=(15, 5))
plt.title('Box Plot', fontsize=18)
plt.xlabel('xlabel',fontsize=18)
sns.boxplot(uni['world_rank'])
# Out:
# <AxesSubplot:title={'center':'Box Plot'}, xlabel='world_rank'>

# %%
f, axarr = plt.subplots(2, 2, figsize=(14, 8))
plt.suptitle('World university rankings Breakdown', fontsize=18)

sns.kdeplot(uni['world_rank'], ax=axarr[0][0])
sns.kdeplot(uni['national_rank'], ax=axarr[0][1])
sns.countplot(uni['broad_impact'], ax=axarr[1][0])
sns.kdeplot(uni['patents'], ax=axarr[1][1])
# Out:
# <AxesSubplot:xlabel='patents', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis

# %%
# Bar plot
 
sns.barplot(x=uni['world_rank'].head(10), y=uni['quality_of_education'])
# Out:
# <AxesSubplot:xlabel='world_rank', ylabel='quality_of_education'>

# %%
sns.barplot(x=uni['world_rank'].head(10), y=uni['publications'])
# Out:
# <AxesSubplot:xlabel='world_rank', ylabel='publications'>

# %% [markdown]
# # Scatterplot
#
# Top 5 Universities from year 2012 & 2015
#
# The scatterplot below shows the top 5 univerisities in 2012 & 2015

# %%
#2012

uni1=uni[uni.year==2012]
uni1.head(5)
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
university2012 = uni1.head(10)
plt.scatter(university2012.country,university2012.institution,) 
plt.xlabel('countries')
plt.ylabel('universities')
plt.title('Rank in 2012')
plt.show()

# %%
#2013
uni2=uni[uni.year==2013]
uni2.head(5)
# Out:
#      world_rank                            institution         country  \
# 100           1                     Harvard University             USA
# 101           2                    Stanford University             USA
# 102           3                   University of Oxford  United Kingdom
# 103           4  Massachusetts Institute of Technology             USA
# 104           5                University of Cambridge  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 100              1                     1                  1
# 101              2                    11                  2
# 102              1                     7                 12
# 103              3                     2                 16
# 104              2                     3                 15
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 100                   1             1          1          1           NaN
# ...

# %%
university2013 = uni2.head(10)
plt.scatter(university2013.country,university2013.institution,) 
plt.xlabel('countries')
plt.ylabel('universities')
plt.title('Rank in 2013')
plt.show()

# %%
uni3=uni[uni.year==2014]
uni3.head(5)
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# ...

# %%
university2014 = uni3.head(10)
plt.scatter(university2014.country,university2014.institution,) 
plt.xlabel('countries')
plt.ylabel('universities')
plt.title('Rank in 2014')
plt.show()

# %%
uni4=uni[uni.year==2015]
uni4.head(5)
# Out:
#       world_rank                            institution         country  \
# 1200           1                     Harvard University             USA
# 1201           2                    Stanford University             USA
# 1202           3  Massachusetts Institute of Technology             USA
# 1203           4                University of Cambridge  United Kingdom
# 1204           5                   University of Oxford  United Kingdom
#
#       national_rank  quality_of_education  alumni_employment  \
# 1200              1                     1                  1
# 1201              2                     9                  2
# 1202              3                     3                 11
# 1203              1                     2                 10
# 1204              2                     7                 13
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 1200                   1             1          1          1           1.0
# ...

# %%
university2015 = uni4.head(10)
plt.scatter(university2015.country,university2015.institution,) 
plt.xlabel('countries')
plt.ylabel('universities')
plt.title('Rank in 2015')
plt.show()

# %% [markdown]
# # Line Plots

# %%
#Let us see the progress scores for the top 5 universities from year 2012 & 2015 using line charts!
#Harvard University
#Harvard has maintained a score of 100 from 2014-2015.

years = [2012,2013,2014,2015]
score = [100,100,100,100]
plt.plot(years, score)
plt.xlabel('Year')
plt.ylabel('Score')
plt.title("Harvard University");

# %%
#MIT
years = [2012,2013,2014,2015]
score = [91.67,91.45,98.69,97.54]
plt.plot(years, score)
plt.xlabel('Year')
plt.ylabel('Score')
plt.title("MIT");

# %%
#Stanford University
years = [2012,2013,2014,2015,]
score = [89.5,93.94,99.09,98.66]
plt.plot(years, score)
plt.xlabel('Year')
plt.ylabel('Score')
plt.title("Stanford University");

# %%
#University of Cambridge

years = [2012,2013,2014,2015]
score = [86.17,90.24,97.64,96.81]
plt.plot(years, score)
plt.xlabel('Year')
plt.ylabel('Score')
plt.title("University of Cambridge");

# %%
#University of Oxford

years = [2012,2013,2014,2015]
score = [82.34,92.54,97.51,96.46]
plt.plot(years, score)
plt.xlabel('Year')
plt.ylabel('Score')
plt.title("University of Oxford");

# %% [markdown]
# Jointplot

# %%
sns.jointplot(uni.world_rank, uni.broad_impact)

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# Heatmap

# %%
corr = uni.corr(method = 'spearman')
plt.figure(figsize=(14,7))
plt.title("Correlation Graph")

sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation Graph'}>

# %%
import plotly.figure_factory as ff
# prepare data
dataframe = uni[uni.year == 2015]
data2015 = uni.loc[:,["patents","influence", "citations"]]
data2015["index"] = np.arange(1,len(data2015)+1)
# scatter matrix
fig = ff.create_scatterplotmatrix(data2015, diag='box', index='index',colormap='Portland',
                                  colormap_type='cat',
                                  height=700, width=700)
iplot(fig)
# Out:
# <div>                            <div id="ca8307a2-6146-4fd9-b2a6-8f02d9228082" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca8307a2-6146-4fd9-b2a6-8f02d9228082")) {                    Plotly.newPlot(                        "ca8307a2-6146-4fd9-b2a6-8f02d9228082",                        [{"marker":{"color":"rgb(12, 51, 131)"},"showlegend":false,"xaxis":"x","y":[5,1,15,50,18,101,26,66,5,16,101,10,9,3,7,34,23,29,13,22,101,28,62,33,21,44,20,41,101,57,86,11,35,8,101,29,14,12,101,101,101,19,101,23,32,101,65,101,84,27,51,54,62,101,2,35,101,92,101,101,101,101,101,99,101,101,101,101,74,101,61,85,101,46,4,101,101,101,29,49,46,101,101,86,101,101,40,101,101,101,101,46,101,69,101,100,92,101,101,101,7,11,15,1,39,10,19,101,101,42,17,14,7,5,13,12,2,60,51,22,24
# ...
